# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import rc


data1 = np.loadtxt("sxvar_time_alpha_0.0_N_25_0.0_.txt")
data2 = np.loadtxt("sxvar_time_alpha_0.0_N_25_14.9309177_.txt")
data3 = np.loadtxt("sxvar_time_alpha_0.0_N_25_hz00.0_.txt")
data4 = np.loadtxt("sxvar_time_alpha_0.0_N_25_hz014.9309177_.txt")
dd1, dd2, dd3,dd4 = data1,data2, data3, data4
t1, t2,t3, t4 = [], [], [], []
sxv1 , sxv2, sxv3, sxv4 = [], [], [], []
for i in range(999):
    t1.append(dd1[i][0])
    sxv1.append(dd1[i][1])
    t2.append(dd2[i][0])
    sxv2.append(dd2[i][1])
    t3.append(dd3[i][0])
    sxv3.append(dd3[i][1])
    t4.append(dd4[i][0])
    sxv4.append(dd4[i][1])
#print(t,sxv)
plt.figure(figsize = (8,9))
plt.subplot(411)
plt.ylim(-1,1)
plt.title(r"latsize = 25, $\beta$ = 0.0, $h_0$ = 25")
plt.ylabel(r'$Sxvar$, $\omega_D=0.0D$')
plt.tick_params(
    axis='x',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom=False,      # ticks along the bottom edge are off
    top=False,         # ticks along the top edge are off
    labelbottom=False)
plt.plot(t1, sxv1)
plt.subplot(412)
plt.ylim(-1,1)
plt.ylabel(r'$Sxvzr$,$\omega_D=14.9309$')
plt.tick_params(axis='x',which='both',bottom=False,top=False,labelbottom=False)
plt.plot(t2,sxv2)
plt.subplot(413)
plt.title(r"latsize = 25, $\beta$ = 0.0, $h_0$ = 0")
plt.tick_params(axis='x',which='both',bottom=False,top=False,labelbottom=False)
plt.plot(t3,sxv3)
plt.ylabel(r'$Sxvar$, $\omega_D=0.0D$')
plt.subplot(414)
plt.plot(t4,sxv4)
plt.ylabel(r'$Sxvr$,$\omega_D=14.9309$')
plt.xlabel("time")
plt.savefig("latsize25beta0.jpeg",dpi = 500)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import rc


data1 = np.loadtxt("sxvar_time_alpha_0.0_N_25_0.0_.txt")
data2 = np.loadtxt("sxvar_time_alpha_0.0_N_25_14.9309177_.txt")
dd1, dd2, dd3,dd4 = data1,data2, data3, data4
t1, t2 = [], []
sxv1 , sxv2 = [], []
for i in range(999):
    t1.append(dd1[i][0])
    sxv1.append(dd1[i][1])
    t2.append(dd2[i][0])
    sxv2.append(dd2[i][1])
#print(t,sxv)
plt.figure(figsize = (12,5))
plt.subplot(211)
plt.ylim(-0.1,0.6)
plt.title(r"latsize = 25, $\beta$ = 0.0, $h_0$ = 25")
plt.ylabel(r'$Sxvar$, $\omega_D=0.0D$')
plt.tick_params(
    axis='x',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom=False,      # ticks along the bottom edge are off
    top=False,         # ticks along the top edge are off
    labelbottom=False)
plt.plot(t1, sxv1)
plt.subplot(212)
plt.ylim(-0.1,0.6)
plt.ylabel(r'$Sxvzr$,$\omega_D=14.9309$')
plt.plot(t2,sxv2)
plt.xlabel("time")
plt.savefig("latsize25beta0.jpeg",dpi = 500)
plt.show()
